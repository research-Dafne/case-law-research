# %%
import sqlalchemy
import pandas as pd
import os

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://dafne@localhost/caselaw?charset=utf8')

# %%
query = '''
    select cta1.target as source, cta2.target as target, count(*) as weight
    from caselaw.links_case_to_article cta1
    join caselaw.links_case_to_article cta2
    on cta1.source = cta2.source
    group by cta1.target, cta2.target
    having count(*)>5 and cta1.target <= cta2.target
    ;
'''
article_to_article = pd.read_sql(query, engine)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e75e795ae84c> in <module>()
#       8     ;
#       9 '''
# ---> 10 article_to_article = pd.read_sql(query, engine)
#
# /home/dafne/anaconda2/envs/caselaw/lib/python3.5/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     414             sql, index_col=index_col, params=params,
#     415             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 416             chunksize=chunksize)
#     417
#     418
#
# /home/dafne/anaconda2/envs/caselaw/lib/python3.5/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1085         args = _convert_params(sql, params)
#    1086
# -> 1087         result = self.execute(*args)
#    1088         columns = result.keys()
#    1089
#
# ...
