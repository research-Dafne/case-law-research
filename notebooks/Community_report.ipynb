# %%
import networkx as nx
import nwtools.communities
import pandas as pd
import os

# %%
filepath = '/media/sf_VBox_Shared/CaseLaw/2018-01-29-lido/derived/'
leg_nodes = pd.read_csv(os.path.join(filepath, 'article_nodes_nodup_min5_gcc.csv'))
leg_edges = pd.read_csv(os.path.join(filepath, 'article_to_article_min5_gcc.csv'))

# %%
leg_edges.head()
# Out:
#     id                                             source  \
# 0  253  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 1  508  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 2  509  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 3  616  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 4  617  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
#
#                                               target  weight
# 0  http://linkeddata.overheid.nl/terms/bwb/id/BWB...      81
# 1  http://linkeddata.overheid.nl/terms/bwb/id/BWB...      32
# 2  http://linkeddata.overheid.nl/terms/bwb/id/BWB...      41
# 3  http://linkeddata.overheid.nl/terms/bwb/id/BWB...       5
# 4  http://linkeddata.overheid.nl/terms/bwb/id/BWB...      14

# %%
leg_nodes.head()
# Out:
#                                                   id  \
# 0  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 1  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 2  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 3  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
# 4  http://linkeddata.overheid.nl/terms/bwb/id/BWB...
#
#                                               title  \
# 0  Algemene wet inzake rijksbelastingen, Artikel 18
# 1        Regeling dierlijke EG-premies, Artikel 2.4
# 2               Handelsregisterwet 2007, Artikel 36
# 3       Arbeidsomstandighedenbesluit, Artikel 4.47c
# 4              Wetboek van Strafrecht, Artikel 323a
#
#                                               label  \
# 0  Algemene wet inzake rijksbelastingen, Artikel 18
# 1        Regeling dierlijke EG-premies, Artikel 2.4
# 2               Handelsregisterwet 2007, Artikel 36
# 3       Arbeidsomstandighedenbesluit, Artikel 4.47c
# 4              Wetboek van Strafrecht, Artikel 323a
#
#                           authority  community  \
# 0                         Financiën          4
# 1                 Economische Zaken          4
# 2                 Economische Zaken        106
# 3  Sociale Zaken en Werkgelegenheid         12
# 4            Veiligheid en Justitie         10
#
#                                    book
# 0  Algemene wet inzake rijksbelastingen
# 1         Regeling dierlijke EG-premies
# 2               Handelsregisterwet 2007
# 3          Arbeidsomstandighedenbesluit
# 4                Wetboek van Strafrecht

# %%
graph = nx.from_pandas_edgelist(leg_edges, source='source', target='target', edge_attr='weight')
partition = leg_nodes.set_index('id')['community'].to_dict()

# %%
com_statistics = nwtools.communities.partition_statistics(partition, graph, weight='weight')

# %%
com_statistics_df = pd.DataFrame.from_dict(com_statistics, orient='index')

# %%
com_statistics_df.sort_values('size', ascending=False).head(10)
# Out:
#     average_internal_degree  average_degree  total_strength  conductance  \
# 4                  9.345809       21.629106         2082565     0.567906
# 2                  6.799551       15.458863          565898     0.560152
# 0                  4.900326       17.506754          846344     0.720089
# 12                 4.170000       12.096429          208967     0.655270
# 10                21.889368       54.438218         3334411     0.597904
# 9                  3.258197        9.151639           20378     0.643977
# 20                 4.436620       15.211268           64237     0.708333
# 3                  4.601896       18.886256           48503     0.756336
# 8                  3.609626       10.502674           18578     0.656314
# 21                 3.289855        8.536232           16747     0.614601
#
#     size  external_degree  internal_strength  weighted_conductance  \
# 4   5023            61699             943852              0.546784
# 2   2674            23155             258009              0.544072
# 0   2147            27066             290011              0.657337
# 12  1400            11097              76346              0.634650
# 10  1392            45308            1542644              0.537356
# 9    244             1438               7288              0.642359
# 20   213             2295              22008              0.657394
# 3    211             3014              12759              0.736944
# 8    187             1289               6799              0.634029
# 21   138              724               7009              0.581477
#
#     average_external_strength  average_internal_strength  internal_degree  \
# 4                  226.699781                 187.906032            46944
# 2                  115.141735                  96.488033            18182
# 0                  259.121099                 135.077317            10521
# 12                  94.729286                  54.532857             5838
# 10                1287.188937                1108.221264            30470
# 9                   53.647541                  29.868852              795
# 20                 198.258216                 103.323944              945
# 3                  169.402844                  60.469194              971
# 8                   62.989305                  36.358289              675
# 21                  70.565217                  50.789855              454
#
#     external_strength  total_degree  average_external_degree  average_strength
# 4             1138713        108643                12.283297        414.605813
# 2              307889         41337                 8.659312        211.629768
# 0              556333         37587                12.606428        394.198416
# 12             132621         16935                 7.926429        149.262143
# 10            1791767         75778                32.548851       2395.410201
# 9               13090          2233                 5.893443         83.516393
# 20              42229          3240                10.774648        301.582160
# 3               35744          3985                14.284360        229.872038
# 8               11779          1964                 6.893048         99.347594
# 21               9738          1178                 5.246377        121.355072

# %%
com_statistics_df.sort_values('weighted_conductance', ascending=False).head(10)
# Out:
#      average_internal_degree  average_degree  total_strength  conductance  \
# 3                   4.601896       18.886256           48503     0.756336
# 134                 1.818182        6.636364             570     0.726027
# 255                 1.000000        4.000000              96     0.750000
# 279                 1.000000        3.333333              53     0.700000
# 246                 0.500000        3.000000              52     0.833333
# 217                 1.000000        3.333333             103     0.700000
# 234                 0.500000        2.000000              34     0.750000
# 39                  7.066176       35.242647          179558     0.799499
# 48                  0.800000        2.600000              89     0.692308
# 122                 3.047619       10.809524            2786     0.718062
#
#      size  external_degree  internal_strength  weighted_conductance  \
# 3     211             3014              12759              0.736944
# 134    11               53                159              0.721053
# 255     3                9                 27              0.718750
# 279     3                7                 15              0.716981
# 246     2                5                 15              0.711538
# 217     3                7                 30              0.708738
# 234     2                3                 10              0.705882
# 39    136             3832              53386              0.702681
# 48      5                9                 29              0.674157
# 122    21              163                923              0.668701
#
#      average_external_strength  average_internal_strength  internal_degree  \
# 3                   169.402844                  60.469194              971
# 134                  37.363636                  14.454545               20
# 255                  23.000000                   9.000000                3
# 279                  12.666667                   5.000000                3
# 246                  18.500000                   7.500000                1
# 217                  24.333333                  10.000000                3
# 234                  12.000000                   5.000000                1
# 39                  927.735294                 392.544118              961
# 48                   12.000000                   5.800000                4
# 122                  88.714286                  43.952381               64
#
#      external_strength  total_degree  average_external_degree  \
# 3                35744          3985                14.284360
# 134                411            73                 4.818182
# 255                 69            12                 3.000000
# 279                 38            10                 2.333333
# 246                 37             6                 2.500000
# 217                 73            10                 2.333333
# 234                 24             4                 1.500000
# 39              126172          4793                28.176471
# 48                  60            13                 1.800000
# 122               1863           227                 7.761905
#
#      average_strength
# 3          229.872038
# 134         51.818182
# 255         32.000000
# 279         17.666667
# 246         26.000000
# 217         34.333333
# 234         17.000000
# 39        1320.279412
# 48          17.800000
# 122        132.666667
